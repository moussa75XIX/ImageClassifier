# %% [markdown]
# # Projet de classificaion de drapeaux : Rapport

# %% [markdown]
# Ce rapport a pour but de démontrer les résultats que j'ai pu obtenir après 1 mois de travail. L'objectif du projet etait de pouvoir déterminer à quel pays appartient une image représentant son drapeau national.
# Pour ce faire nous devions créer et entrainer plusieurs PMC avec une configuration précise jusqu'a convergence. Une fois les modèles entrainées et pret à predire nous devions developper une application web permettant à un utilisateur d'importer une image et de réaliser des prédictions dessus.
# La lecture de ce rapport permettra de voir les résultats que j'ai obtenu en developpant des modèles PMC avec la librairie Keras de Tensorflow ainsi que les résultats que j'ai obtenu en essayant de résoudre la problématique de base en utilisant une librairie C++ contenant les méthodes nécessaires à la création, la sauvegarde, l'entrainement et la suppression d'un PMC.

# %% [markdown]
# ## Prédictions obtenues avec les modèles Tensorflow Keras :

# %%
import tensorflow as tf
import datetime
import os
import numpy as np
import ctypes
from PIL import Image

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
CLASSES = ["espagne", "france", "japon"]
CLASSES_SIZE = len(CLASSES)

# %%
def predict(model,CLASSES,CLASSES_SIZE,img_path):

    image = Image.open(img_path)
    image = image.resize((64, 64))
    if image.mode in ("RGB", "P"): image = image.convert("RGBA")

    im_arr = np.array(image).flatten()
    im_arr = im_arr / 255.0
    im_arr = im_arr.tolist()

    dataset_inputs_size = len(im_arr)
    dataset_inputs_type = ctypes.c_float * dataset_inputs_size

    im_arr = np.array(im_arr)

    img_batch = np.expand_dims(im_arr, axis=0)

    prediction = model.predict(img_batch)

    prediction_list = prediction.tolist()

    flat_list = []
    for sublist in prediction_list:
        for item in sublist:
            flat_list.append(item)

            tab_predict = []

    for q in range(3):
        tab_predict.append(flat_list[q])

    max_tab = max(tab_predict)
    prediction_percent = 0

    for i in range(CLASSES_SIZE):
        if tab_predict[i] == max_tab:
            prediction_percent = (tab_predict[i])

    if prediction_percent == tab_predict[0]:
        prediction_class = CLASSES[0]
    elif prediction_percent == tab_predict[1]:
        prediction_class = CLASSES[1]
    else:
        prediction_class = CLASSES[2]

    print(tab_predict)
    print(prediction_class)

    return prediction_class

# %%
model_a = tf.keras.models.load_model("../models/keras_models/model_a.h5")
model_b = tf.keras.models.load_model("../models/keras_models/model_b.h5")
model_c = tf.keras.models.load_model("../models/keras_models/model_c.h5")
model_d = tf.keras.models.load_model("../models/keras_models/model_d.h5")

img_path = r"..\dataset\test\france\267.png"
Image.open(img_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=64x64 at 0x1CF09563B80>

# %% [markdown]
# Prédiction sur le model_a : PMC sans couche cachée

# %%
predict(model_a, CLASSES, CLASSES_SIZE, img_path)
# Out:
# [0.0008665071800351143, 0.9941648840904236, 0.004968627355992794]
# france
# 'france'

# %% [markdown]
# Le modèle indique que cette image a 99,4% de chance d'etre un drapeau du pays : France.

# %%
################################################################################################################################

# %% [markdown]
# Prédiction sur le model_b : PMC avec une couche cachée de 8 neurones

# %%
predict(model_b, CLASSES, CLASSES_SIZE, img_path)
# Out:
# [9.356132068205625e-05, 0.9988601207733154, 0.0010463217040523887]
# france
# 'france'

# %% [markdown]
# Le modèle indique que cette image a 99,8% de chance d'etre un drapeau du pays : France.

# %%
################################################################################################################################

# %% [markdown]
# Prédiction sur le model_c : PMC avec une couche cachée de 32 neurones

# %%
predict(model_c, CLASSES, CLASSES_SIZE, img_path)
# Out:
# [0.00022836218704469502, 0.998384952545166, 0.001386698568239808]
# france
# 'france'

# %% [markdown]
# Le modèle indique que cette image a 99,8% de chance d'etre un drapeau du pays : France.

# %%
################################################################################################################################

# %% [markdown]
# Prédiction sur le model_d : PMC avec une couche cachée de 32 neurones

# %%
predict(model_d, CLASSES, CLASSES_SIZE, img_path)
# Out:
# [0.00042562565067783, 0.9945447444915771, 0.005029636900871992]
# france
# 'france'

# %% [markdown]
# Le modèle indique que cette image a 99,4% de chance d'etre un drapeau du pays : France.

# %% [markdown]
# ## Analyses des courbes sur les modèles Tensorflow Keras

# %%
from IPython.display import Image

# %% [markdown]
# Pour chaque entrainement, j'ai sauvegardé les logs grace à la fonction callback de Keras.
# Ce qui permet d'avoir des graphiques genérés par Tensoboard representant les courbes de loss et d'accuracy des différents modèles. Ainsi nous pouvons analyser les résultats des modèles et les interpréter

# %% [raw]
# loss = courbe de la loss du modèle sur le dataset de train
# val_loss = courbe de la loss du modèle sur le dataset de validation (test)
# acc = courbe d'accuracy du modèle sur le dataset de train
# val_acc = courbe d'accuracy du modèle sur le dataset de validation (test)

# %% [markdown]
# ## model_a : MLP sans couches cachées

# %% [markdown]
# ### Courbe de Loss :

# %%
Image('../models/keras_models/images/loss_model_a.png')

# %% [raw]
# La courbe loss diminue tout au long de l’apprentissage jusqu’à convergence. Au bout de 1000 epoch nous avons une loss de 0.08 sur les données d'entrainement tandis que nous avons une loss de 0.67 sur les données de validation. On observe que la courbe val_loss diminue à son maximum entre l’epoch 110-120 puis se met à augmenter. On peut donc en déduire que le modèle est dans une situation d’overfitting.

# %% [markdown]
# ### Courbe d'accuracy :

# %%
Image('../models/keras_models/images/acc_model_a.png')

# %% [raw]
# La courbe acc augmente jusqu’à atteindre 99,5% d’accuracy, la courbe val_acc atteint sa convergence à environ 75% pour atteindre 73,3% au bout de 1000 epoch. Il y a donc un écart d'environ 25% dans l’accuracy entre la courbe acc et la courbe val_acc. Cet écart montre que le modèle généralise mal, il a un niveau de performance faible sur des nouvelles données, et cela confirme donc la situation d’overfitting.
#
# Le modèle ne contient aucune couche cachée, donc pour remedier à ce probleme d’overfitting, les solutions peuvent être de mettre en place de la régularisation ou bien d’augmenter le nombre d’images dans le dataset de train.

# %% [markdown]
# ## model_b : MLP avec 1 couche cachée de 8 neurones

# %% [markdown]
# ### Courbe de Loss :

# %%
Image('../models/keras_models/images/loss_model_b.png')

# %% [raw]
# La courbe loss diminue tout au long de l’apprentissage jusqu’à convergence. Au bout de 1000 epoch nous avons une loss de 0.14 sur les données d'entrainement tandis que nous avons une loss de 0.79 sur les données de validation. On observe que la courbe val_loss diminue à son maximum entre l’epoch 230-250 puis se met à augmenter.
# Le model_b a le meme comportement que le model_a, il est en situation d'overfitting.

# %% [markdown]
# ### Courbe d'accuracy :

# %%
Image('../models/keras_models/images/acc_model_b.png')

# %% [raw]
# La courbe acc augmente jusqu’à atteindre 97,7% d’accuracy, la courbe val_acc atteint sa convergence à environ 77-78% pour atteindre 73,3% au bout de 1000 epoch. Il y a donc un écart de + 20% dans l’accuracy entre la courbe acc et la courbe val_acc. Cet écart montre que le modèle généralise mal, il a un niveau de performance faible sur des nouvelles données, et cela confirme donc la situation d’overfitting.
#
# Le modèle contient 1 couche cachée de 8 neurones, donc pour remedier à ce probleme d’overfitting, les solutions peuvent être de mettre en place de la régularisation, de mettre en place du dropout ou bien d’augmenter le nombre d’images dans le dataset de train.

# %% [markdown]
# ## model_c : MLP avec 1 couche cachée de 32 neurones

# %% [markdown]
# ### Courbe de Loss :

# %%
Image('../models/keras_models/images/loss_model_c.png')

# %% [raw]
# La courbe loss diminue tout au long de l’apprentissage jusqu’à convergence. Au bout de 1000 epoch nous avons une loss de 0.19 sur les données d'entrainement tandis que nous avons une loss de 0.77 sur les données de validation. On observe que la courbe val_loss diminue à son maximum entre l’epoch 100-150 puis se met à augmenter.
# Le model_c a le meme comportement que les model_a et model_b, il est en situation d'overfitting.

# %% [markdown]
# ### Courbe d'accuracy :

# %%
Image('../models/keras_models/images/acc_model_c.png')

# %% [raw]
# La courbe acc augmente jusqu’à atteindre 100% d’accuracy, la courbe val_acc atteint sa convergence à environ 77-78% pour arriver à 75,8% d'accuracy au bout de 1000 epoch. Il y a donc un écart d'environ 25% dans l’accuracy entre la courbe acc et la courbe val_acc. Cet écart montre que le modèle généralise mal, il a un niveau de performance faible sur des nouvelles données, et cela confirme donc la situation d’overfitting.
#
# Le modèle contient 1 couche cachée de 32 neurones, donc pour remedier à ce probleme d’overfitting, les solutions peuvent être de mettre en place de la régularisation, de mettre en place du dropout ou bien d’augmenter le nombre d’images dans le dataset de train.

# %% [markdown]
# ## model_d : MLP avec 2 couches cachées de 32 neurones

# %% [markdown]
# ### Courbe de Loss :

# %%
Image('../models/keras_models/images/loss_model_d.png')

# %% [raw]
# La courbe loss diminue tout au long de l’apprentissage jusqu’à convergence. Au bout de 1000 epoch nous avons une loss inferieure a 0.01 sur les données d'entrainement tandis que nous avons une loss de 0.95 sur les données de validation. On observe que la courbe val_loss diminue à son maximum entre l’epoch 200-250 puis se met à augmenter.
# Le model_c a le meme comportement que les model_a, model_b et model_c, il est en situation d'overfitting.
# On remarque également que l'ecart entre la courbe loss et la courbe val_loss est plus grand que pour les 3 premiers modèles.

# %% [markdown]
# ### Courbe d'accuracy :

# %%
Image('../models/keras_models/images/acc_model_d.png')

# %% [raw]
# La courbe acc augmente jusqu’à atteindre 100% d’accuracy, la courbe val_acc atteint sa convergence à environ 78-79% pour arriver à 74,2% d'accuracy au bout de 1000 epoch. Il y a donc un écart d'environ 25% dans l’accuracy entre la courbe acc et la courbe val_acc. Cet écart montre que le modèle généralise mal, il a un niveau de performance faible sur des nouvelles données, et cela confirme donc la situation d’overfitting.
#
# Le modèle contient 2 couches cachées de 32 neurones, donc pour remedier à ce probleme d’overfitting, les solutions peuvent être de mettre en place de la régularisation, de mettre en place du dropout ou bien d’augmenter le nombre d’images dans le dataset de train.

# %% [markdown]
# ## Comparatif des 4 modèles

# %% [markdown]
# ### Courbes de loss :

# %%
Image('../models/keras_models/images/loss_model_abcd.png')

# %% [raw]
# Nous pouvons remarquer que les valeurs de loss des 4 modèles ont les mêmes tendances, elles diminuent jusqu’à convergence. Cependant le model_d avec les couches cachées de 32 neurones atteint la loss la plus faible.
#
# Concernant les courbes val_loss, nous observons qu'elles ont les mêmes tendances, elles diminuent jusqu’aux epoch 100-200 et augmentent ensuite. Au bout de 1000 epoch, le modèle A possede la loss la plus faible et le modele D la loss le plus elevé. Cela confirme la situation d’overfitting car le modèle D est le plus complexe, c’est celui qui a le plus tendance à etre sujet à du surapprentissage de part sa structure de 2 couches cachées de 32 neurones.

# %% [markdown]
# ### Courbes d'accuracy :

# %%
Image('../models/keras_models/images/acc_model_abcd.png')

# %% [raw]
# Nous observons que les courbes val_acc ont les mêmes tendances, elles augmentent puis se mettent à stagner au bout de 75% d'accuracy en moyenne. Le modèle ayant la meilleure accuracy au bout de 1000 itérations est le modèle D. C’est le modèle le plus complexe qui a donc la meilleur précision.
#
# Parmis les 4 modèles qui ont été entrainés, le model_c semble être celui qui a les meilleurs performances quantitatives. Cependant, comme les autres modèles : il est sujet à l’overfitting. Donc pour améliorer ses performances, il faudrait réduire cet effet d’overfitting. Il serait intéressant d’ajouter du dropout, de mettre en place de la régularisation et/ou d’augmenter le volume de données d’apprentissage en faisant de la data augmentation (rotation des images).

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# Parmis les 4 modèles qui ont été entrainés, les model_c et model_d ont la meilleure précision, que ce sur des données qu'ils connaissent ou non.
# Les model_a et model_b sont ceux qui ont une plus grande valeur de loss sur les données d'entrainement. Cependant, le model_a est celui qui possède la valeur de loss la plus faible tandis que le model_d possède la plus haute valeur de loss.
#
# Ainsi, on en déduit alors que les modèles les plus complexes possèdent la meilleure précision et sont plus sensible à l'overfitting.
#
# Cependant on remarque que tout les modèles ont cette tendance à etre en overfitting. Donc pour améliorer leurs performances, il faudrait réduire cet effet d’overfitting. Il serait intéressant d’ajouter du dropout, de mettre en place de la régularisation et/ou d’augmenter le volume de données d’apprentissage en faisant de la data augmentation (rotation des images).

# %% [markdown]
# ## Prédictions obtenues avec les modèles de la libraire C++ :
